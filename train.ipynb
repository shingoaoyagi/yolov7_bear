# %%
# %cd /content/drive/MyDrive/Colab/bear_alert_project

# %%
# !git clone https://github.com/WongKinYiu/yolov7

# %%
# %cd yolov7

# %%
# !pip install -r requirements.txt

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-e6e.pt

# %%
# !python train.py --workers 8 --batch-size 16 \
  --data /content/drive/MyDrive/Colab/bear_alert_project/dataset/data.yaml \
  --cfg cfg/training/yolov7x.yaml \
  --weights 'yolov7x.pt' \
  --name yolov7x-bear \
  --hyp data/hyp.scratch.p5.yaml \
  --epochs 300 \
  --device 0
