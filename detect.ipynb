# %%
# !python detect.py --source /content/drive/MyDrive/Colab/bear_alert_project/test/bear1.jpeg \
  --weights /content/drive/MyDrive/Colab/bear_alert_project/yolov7/runs/train/yolov7x-bear2/weights/best.pt \
  --conf 0.2 \
  --img-size 640 \
  --device 0
